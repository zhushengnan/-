# %%
ggplot2绘图系统

# %%
用语法作图，数据映射到几何客体（points、lines、bars）的美学属性（颜色/形状/大小）

# %%
=基本绘图系统+Lattice绘图系统

# %%
可以自动处理标题/文字说明/空间等，但也允许通过添加注释进行修改

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
绘图函数

# %%
qplot()

# %%
类似于Base系统的plot（），参数包含aesthetics/geom/fact

# %%
隐藏了绘图实现的细节

# %%
ggplot()

# %%
是核心，可以实现qplot()无法实现的功能

# %%
调用ggplot()本省并不能实现绘图，要在基础上添加层才可以
