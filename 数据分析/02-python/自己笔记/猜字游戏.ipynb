# %%
temp=input("猜个数字：")
guess = int(temp)
if guess == 8:
   print("恭喜你，猜对了")
   print("可惜没有奖励")
else:
   print ("你猜错了")
print("游戏结束，不玩了")
# Out:
# 猜个数字：8
# 恭喜你，猜对了
# 可惜没有奖励
# 游戏结束，不玩了

# %%
temp=input("猜个数字：")
guess = int(temp)
if guess == 8:
   print("恭喜你，猜对了")
   print("可惜没有奖励")
else:
   if guess>8:
      print('大了')
   else:
      print("小了")
print("游戏结束，不玩了")

# %%
temp=input("猜个数字：")
guess = int(temp)
while guess !=8:
  if guess == 8:
    print("恭喜你，猜对了")
    print("可惜没有奖励")
  else:
    if guess > 8:
       print('大了')
     else:
       print('小了')
print("游戏结束，不玩了")
