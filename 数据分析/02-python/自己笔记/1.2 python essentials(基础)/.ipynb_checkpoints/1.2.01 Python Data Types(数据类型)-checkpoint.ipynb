# %% [markdown]
# # Python数据类型

# %% [markdown]
# 常用数据类型 Common Data  Types

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# 其他类型 Others

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# # 数据类型分类

# %% [markdown]
#  可变和不可变类型 mutable and immutable data types

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
可变变量，对list进行操作，list内部的内容是会变化的

# %%
a=['c','b','a']
a.sort()
a
# Out:
# ['a', 'b', 'c']

# %%
对于不可变对象，对str进行操作，不会有变化

# %%
a='abc'
a.replace('a','A')
# Out:
# 'Abc'

# %%
a
# Out:
# 'abc'

# %% [markdown]
# ![_auto_0](attachment:_auto_0)
