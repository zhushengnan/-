# %%
运算符和函数

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
%运算符是用来格式化字符串的

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
chr()函数把编码转换成对应的字符

# %%
chr(66)
# Out:
# 'B'

# %%
format()格式化字符串

# %%
len()函数表示字符串包含的字符数

# %%
len('ABC')
# Out:
# 3

# %%
len('中文'.encode('utf-8'))#字符串转换为字节，则计算的维字节数
# Out:
# 6

# %%
ord()函数获取字符的整数表示

# %%
ord('A')
# Out:
# 65

# %%
random模块

# %%
randint()返回一个随机整数
