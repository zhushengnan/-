# %% [markdown]
# # 字符串String

# %% [markdown]
# 字符串时以单引号或双引号括起来的任意文本，‘’或“”只是一种表示方式，不是字符串的一部分

# %% [markdown]
# ### 字符串的生成，单引号与双引号是等价的：

# %%
s = "hello world"
print(s)
# Out:
# hello world

# %%
s = 'hello world'
print(s)
# Out:
# hello world

# %%
s = 'hello world'
s
# Out:
# 'hello world'

# %% [markdown]
# （在仅用变量名时，输出的字符串是被用单引号括起来了的。这是为了让非字符串对象也能以字符串的方式显示在屏幕上－－即它显示的是该对象的字符串表示，而不仅仅是字符串本身。引号表示你刚刚输入的变量的值是一个字符串。）

# %% [markdown]
# ### 字符串内部既包含‘’又包含“”，可以用转义字符\来标识。

# %%
print('I\'m \"OK"!')
# Out:
# I'm "OK"!

# %% [markdown]
# 转义字符\可以转移很多字符。\n表示换行,\t表示制表符,\本身也要转义，所以\ \表示的字符就是\

# %%
print('I\'m learning\nPython')
# Out:
# I'm learning
# Python

# %%
print('\\\n\\')
# Out:
# \
# \

# %% [markdown]
# 如果字符串里面有很多字符都需要转义，就需要加很多\，为了简化，Python允许使用r''表示内部字符串默认不转义

# %%
print('\\\t\\')
# Out:
# \	\

# %%
print(r'\\\t\\')
# Out:
# \\\t\\

# %% [markdown]
# 在字符串最后为\会报错，可再添加空格键，或者\\

# %% [markdown]
# ### 三引号用来输入包含多行文字的字符串

# %% [markdown]
# 如果字符串内部有很多换行，用\n写在一行里不好阅读，为了简化，Python允许用'''...'''的格式表示多行内容。

# %% [markdown]
# 注意在输入多行内容时，提示符由>>>变为...，提示你可以接着上一行输入，注意...是提示符，不是代码的一部分：

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# ### 多个字符串，用逗号“,”隔开，就可以连成一串输出

# %% [markdown]
# print()会依次打印每个字符串，遇到逗号“,”会输出一个空格

# %%
print('The quick brown fox','jumps over','the lazy dog')
# Out:
# The quick brown fox jumps over the lazy dog

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
字符串的加法：

# %%
s = "hello" + " world"
s

# %%
字符串索引：

# %%
s[0]

# %%
字符串的分割：

# %%
s = "hello world"
s.split()

# %%
字符串的格式化

# %%
%运算符是用来格式化字符串的

# %% [markdown]
# ![_auto_1](attachment:_auto_1)

# %%
print("I'm %s. I'm %d year old" % ('Vamei', 99))#"I'm %s. I'm %d year old" 为我们的模板。%s为第一个格式符，表示一个字符串。%d为第二个格式符，表示一个整数。('Vamei', 99)的两个元素'Vamei'和99为替换%s和%d的真实值。 
#在模板和tuple之间，有一个%号分隔，它代表了格式化操作。
# Out:
# I'm Vamei. I'm 99 year old

# %%
%[(name)][flags][width].[precision]typecode

(name)为命名

flags可以有+,-,' '或0。+表示右对齐。-表示左对齐。' '为一个空格，表示在正数的左侧填充一个空格，从而与负数对齐。0表示使用0填充。

width表示显示宽度

precision表示小数点后精度

# %%
字符串与编码

# %% [markdown]
# https://www.liaoxuefeng.com/wiki/0014316089557264a6b348958f449949df42a6d3a2e542c000/001431664106267f12e9bef7ee14cf6a8776a479bdec9b9000
